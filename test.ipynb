# %%
from pyEnergy.clusters.kmeans import Kmeans 
from pyEnergy.composition.composition import Composer
from pyEnergy.fool import Fool
path = "data/ChangErZhai-40-139079-values 20180101-20181031.csv"
print(path)
fool = Fool(path).select(method='corr', params={"threshold": 0.6})
print("fool init.")
# Out:
# data/ChangErZhai-40-139079-values 20180101-20181031.csv
# Selected features (correlation-based):
# std. real power(ss)
# ave. real power(ss)
# trend real power(ss)
# trend phase B current(ss)
# fool init.

# %%
fool.feature
# Out:
#      std. real power(ss)  ave. real power(ss)  trend real power(ss)  \
# 0               0.504825            -0.334844              0.882210
# 1              -0.124600            -0.315711             -0.287347
# 2              -0.899000            -0.313480              0.214631
# 3              -0.786107            -0.334862              0.202810
# 4               0.410218            -0.391474             -0.156846
# ..                   ...                  ...                   ...
# 117            -0.977356             0.202501              0.535787
# 118            -0.788531             0.186898              0.560745
# 119            -0.154261            -1.284586              0.547553
# 120             0.030899            -1.222181              0.522405
# 121            -0.589055             0.782970             -1.987212
#
#      trend phase B current(ss)
# 0                     0.119922
# 1                     0.388508
# 2                     0.521527
# 3                     0.237628
# 4                     0.356995
# ..                         ...
# 117                   0.333231
# 118                   0.440903
# 119                   0.865761
# 120                   0.220339
# 121                  -0.787280
#
# [93 rows x 4 columns]

# %%
model = Kmeans(fool)
y_pred = model.fit()
model.plot()
# Out:
# best_n_clusters: 3, score: 0.5937076408114003
# /opt/miniconda3/envs/nilm/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
print(y_pred)
composer = Composer(fool, y_pred)
print('composer init.')
composer.set_param('curnt_B')
composer.set_reducer('')

composer.compose(index=2)
composer.plot()
